# %%
import openai
from IPython.display import clear_output
from time import sleep

QuestionCategories = [
                        {"name":"SQL","keyword":"SQL"},
                        {"name":"Computer Networks","keyword":"Computer Networks"},
                        {"name":"Python Functions","keyword":"Python Functions"},
                        {"name":"Python data types","keyword":"Python data types"},
                        {"name":"Parity Check","keyword":"Simple parity check"},
                     ]

api_key="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"


def GetQuestion(topic):
        # Set up the OpenAI API client
        openai.api_key = api_key

        # Set up the model and prompt
        model_engine = "text-davinci-003"
        prompt = f"""
        Give me an MCQ on {topic} with answer and explanation. Give 4 choices numbered from 1 to 4. 
        Provide answer as only answer number without any text at all not even the word Answer.
        Separate the question,each choice,answer and explanation with the character ||.

        """

        # Generate a response
        completion = openai.Completion.create(
            engine=model_engine,
            prompt=prompt,
            max_tokens=1024,
            n=1,
            stop=None,
            temperature=0.5,
        )

        response = completion.choices[0].text
        response = completion.choices[0].text
        L1=response.split("||")
        question={}
        question["q"]= L1[0]
        question["choice1"] = L1[1]
        question["choice2"] = L1[2]
        question["choice3"] = L1[3]
        question["choice4"] = L1[4]
        question["answer"] = int(L1[5])
        question["explanation"] = L1[6]
        return(question)



def PrintMenu():
   
        print("Select a category for your question : ")
        i = 1
        for c in  QuestionCategories:
            print(i,".",c["name"],flush=True)
            i+=1
        print("0. Exit",flush=True)    

        r=int(input("Enter your choice : "))
        return r
def main():
    
    choice=1
    while choice != 0:
        clear_output(wait=True)
        #sleep(1)
        choice=PrintMenu()
        if choice == 0:
            break
       
        topic= QuestionCategories[choice-1]["keyword"]
        print(topic, "Fetching question from ChatGPT...")
        question=GetQuestion(topic)
        clear_output(wait=True)
        print(question["q"],"\n")
        print(question["choice1"])
        print(question["choice2"])
        print(question["choice3"])
        print(question["choice4"])
        user_answer = int(input("Enter answer (1-4) :"))
        if user_answer == question["answer"]:
            print("Correct")
        else:
           print("Incorrect")
           print("Correct answer is",question["answer"]) 
        print(question["explanation"])    
        input("Press any key to continue")
        
        

    

main()
# Out:
# Q. What is the purpose of the GROUP BY clause in SQL?
#
# 1. To sort the result set
# 2. To group rows into summary rows
# 3. To retrieve data from multiple tables
# 4. To limit the number of rows returned
# Enter answer (1-4) :2
# Correct
# Grouping rows into summary rows allows the user to aggregate data from multiple rows into a single row, making it easier to read and interpret the data.
